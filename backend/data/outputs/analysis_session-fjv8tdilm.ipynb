# %% [markdown]
# # AutoDS Analysis Session
# **Session ID:** `session-fjv8tdilm`
# **Date:** 2026-01-17 23:00:30

# %% [markdown]
# ---

# %% [markdown]
# ### User Request
# get the indian data of ev station to compare and create the graphs for the year 2024 to 2025 to see the growth in 1 year interval

# %% [markdown]
# **Action:** Explore dataset structure and columns

# %%
# First, let's explore the dataset structure
print("Dataset Shape:", df.shape)
print("\nColumn Names:")
print(df.columns.tolist())
print("\nFirst few rows:")
print(df.head())
# Out:
# Dataset Shape: (257585, 19)
#
# Column Names:
# ['StationID', 'UUID', 'DataProviderID', 'Operator', 'UsageType', 'UsageCost', 'AddressTitle', 'AddressLine1', 'Town', 'StateOrProvince', 'Postcode', 'Country', 'Latitude', 'Longitude', 'MaxPowerKW', 'FastChargeCount', 'ConnectionTypes', 'StatusType', 'YearCreated']
#
# First few rows:
#    StationID                                  UUID  ...   StatusType YearCreated
# 0     473101  5B1E6265-45A9-4D0E-83A7-AB49D84D0BB2  ...  Operational        2026
# 1     472908  A5EA67A8-756B-4C09-B578-BAEC40AEA237  ...  Operational        2026
# 2     472220  1CCABB37-2CE5-49D4-8DC0-5025BE976BA1  ...  Operational        2025
# 3     471954  0E7B7267-6DEE-4E85-91F4-D11B8FF789A9  ...  Operational        2025
# 4     471953  A4E4A241-BF88-4394-99B2-B0B788FE3287  ...  Operational        2025
#
# [5 rows x 19 columns]

# %% [markdown]
# **Action:** Check available countries in dataset

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check available countries in dataset

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries in the dataset

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]

# %% [markdown]
# **Action:** Check unique countries and their counts

# %%
[["Country"], ["Country"]]
