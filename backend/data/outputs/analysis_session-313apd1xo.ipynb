# %% [markdown]
# # AutoDS Analysis Session
# **Session ID:** `session-313apd1xo`
# **Date:** 2026-01-17 23:03:50

# %% [markdown]
# ---

# %% [markdown]
# ### User Request
# get the indian data of ev station to compare and create the graphs for the year 2024 to 2025 to see the growth in 1 year interval

# %% [markdown]
# **Action:** Check dataframe structure and columns

# %%
print("DataFrame Columns:")
print(df.columns.tolist())
print("\nFirst few rows:")
print(df.head())
print("\nDataFrame Info:")
print(df.info())
# Out:
# DataFrame Columns:
# ['StationID', 'UUID', 'DataProviderID', 'Operator', 'UsageType', 'UsageCost', 'AddressTitle', 'AddressLine1', 'Town', 'StateOrProvince', 'Postcode', 'Country', 'Latitude', 'Longitude', 'MaxPowerKW', 'FastChargeCount', 'ConnectionTypes', 'StatusType', 'YearCreated']
#
# First few rows:
#    StationID                                  UUID  ...   StatusType YearCreated
# 0     473101  5B1E6265-45A9-4D0E-83A7-AB49D84D0BB2  ...  Operational        2026
# 1     472908  A5EA67A8-756B-4C09-B578-BAEC40AEA237  ...  Operational        2026
# 2     472220  1CCABB37-2CE5-49D4-8DC0-5025BE976BA1  ...  Operational        2025
# 3     471954  0E7B7267-6DEE-4E85-91F4-D11B8FF789A9  ...  Operational        2025
# 4     471953  A4E4A241-BF88-4394-99B2-B0B788FE3287  ...  Operational        2025
#
# [5 rows x 19 columns]
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257585 entries, 0 to 257584
# Data columns (total 19 columns):
# ...

# %% [markdown]
# **Action:** Check available countries and years

# %%
[["Country"], ["YearCreated"]]
# Out:
# Success (No output)

# %% [markdown]
# **Action:** Check unique countries and years in data

# %%
[["Country"], ["YearCreated"]]
# Out:
# Success (No output)

# %% [markdown]
# **Action:** Check unique countries and years

# %%
[["Country"], ["YearCreated"]]
# Out:
# Success (No output)

# %% [markdown]
# **Action:** Check unique countries and years in dataset

# %%
[["Country"], ["YearCreated"], {"year": {"df['YearCreated'].max()}": ""}}]
# Out:
# Success (No output)

# %% [markdown]
# **Action:** Check unique countries and years

# %%
[["Country"], ["YearCreated"], {"year": {"df['YearCreated'].max()}": ""}}]
# Out:
# Success (No output)

# %% [markdown]
# **Action:** Check unique countries and years

# %%
[["Country"], ["YearCreated"], {"year": {"df['YearCreated'].max()}": ""}}]
# Out:
# Success (No output)

# %% [markdown]
# **Action:** Check unique countries and years in dataset

# %%
[["Country"], ["YearCreated"], {"Max": {"df['YearCreated'].max()}": ""}}]
# Out:
# Success (No output)

# %% [markdown]
# **Action:** Check unique countries and years

# %%
[["Country"], ["YearCreated"], {"max_year": {"df['YearCreated'].max()}": ""}}]
# Out:
# Success (No output)

# %% [markdown]
# **Action:** Check unique countries and years

# %%
[["Country"], ["YearCreated"], {"max_year": {"df['YearCreated'].max()}": ""}}]
# Out:
# Success (No output)

# %% [markdown]
# ### User Request
# get the indian data of ev station to compare and create the graphs for the year 2024 to 2025 to see the growth in 1 year interval

# %% [markdown]
# **Action:** Check dataframe structure and columns

# %%
print("DataFrame Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nFirst few rows:")
print(df.head())
# Out:
# DataFrame Shape: (257585, 19)
#
# Columns: ['StationID', 'UUID', 'DataProviderID', 'Operator', 'UsageType', 'UsageCost', 'AddressTitle', 'AddressLine1', 'Town', 'StateOrProvince', 'Postcode', 'Country', 'Latitude', 'Longitude', 'MaxPowerKW', 'FastChargeCount', 'ConnectionTypes', 'StatusType', 'YearCreated']
#
# First few rows:
#    StationID                                  UUID  ...   StatusType YearCreated
# 0     473101  5B1E6265-45A9-4D0E-83A7-AB49D84D0BB2  ...  Operational        2026
# 1     472908  A5EA67A8-756B-4C09-B578-BAEC40AEA237  ...  Operational        2026
# 2     472220  1CCABB37-2CE5-49D4-8DC0-5025BE976BA1  ...  Operational        2025
# 3     471954  0E7B7267-6DEE-4E85-91F4-D11B8FF789A9  ...  Operational        2025
# 4     471953  A4E4A241-BF88-4394-99B2-B0B788FE3287  ...  Operational        2025
#
# [5 rows x 19 columns]

# %% [markdown]
# **Action:** Check available countries and years

# %%
[["Country"], ["YearCreated"]]
# Out:
# Success (No output)

# %% [markdown]
# **Action:** Check unique countries and years in data

# %%
[["Country"], ["YearCreated"]]
# Out:
# Success (No output)

# %% [markdown]
# **Action:** Check unique countries and years

# %%
[["Country"], ["YearCreated"]]
# Out:
# Success (No output)
